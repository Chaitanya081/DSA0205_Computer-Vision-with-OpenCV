# %% [markdown]
# <a href="https://colab.research.google.com/github/Chaitanya081/DSA0205_Computer-Vision-with-OpenCV/blob/main/Daily_practice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Image Smoothing

# %%
from google.colab.patches import cv2_imshow
import cv2

img = cv2.imread("image.jpg")

smoothed_img = cv2.blur(img, (5,5))

print("Original Image")
cv2_imshow(img)

print("Image after Smoothing (Average Filter 5x5)")
cv2_imshow(smoothed_img)
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=197x255>
# Image after Smoothing (Average Filter 5x5)
# <PIL.Image.Image image mode=RGB size=197x255>

# %% [markdown]
# Image Sharpening

# %%
from google.colab.patches import cv2_imshow
import cv2
import numpy as np

img = cv2.imread("image.jpg")

kernel = np.array([[0, -1, 0],
                   [-1, 5, -1],
                   [0, -1, 0]])

sharpened_img = cv2.filter2D(img, -1, kernel)

print("Original Image")
cv2_imshow(img)
print("Image after Sharpening")
cv2_imshow(sharpened_img)
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=197x255>
# Image after Sharpening
# <PIL.Image.Image image mode=RGB size=197x255>

# %% [markdown]
# Mean Filter

# %%
from google.colab.patches import cv2_imshow
import cv2

img = cv2.imread("image.jpg")

mean_img = cv2.blur(img, (5,5))

print("Original Image")
cv2_imshow(img)

print("Image after Mean Filtering")
cv2_imshow(mean_img)
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=197x255>
# Image after Mean Filtering
# <PIL.Image.Image image mode=RGB size=197x255>

# %% [markdown]
# Median Filter

# %%
from google.colab.patches import cv2_imshow
import cv2

img = cv2.imread("image.jpg")

median_img = cv2.medianBlur(img, 5)

print("Original Image")
cv2_imshow(img)

print("Image after Median Filtering")
cv2_imshow(median_img)
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=197x255>
# Image after Median Filtering
# <PIL.Image.Image image mode=RGB size=197x255>

# %% [markdown]
# Guassian Filtering

# %%
from google.colab.patches import cv2_imshow
import cv2

img = cv2.imread("image.jpg")

gaussian_img = cv2.GaussianBlur(img, (5,5), 0)

print("Original Image")
cv2_imshow(img)

print("Image after Gaussian Filtering")
cv2_imshow(gaussian_img)
# Out:
# Original Image
# <PIL.Image.Image image mode=RGB size=197x255>
# Image after Gaussian Filtering
# <PIL.Image.Image image mode=RGB size=197x255>
